# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

fashion_mnist=keras.datasets.fashion_mnist

(x_train,y_train),(x_test,y_test)=fashion_mnist.load_data()

x_train,x_test=x_train/255.0,x_test/255.0

x_train=x_train.reshape(-1,28,28,1)
x_test=x_test.reshape(-1,28,28,1)

print(f"Форма тренировочного набора: {x_train.shape}")
print(f"Форма тестового набора: {x_test.shape}")
# Out:
# Форма тренировочного набора: (60000, 28, 28, 1)
# Форма тестового набора: (10000, 28, 28, 1)

# %%
model=keras.Sequential([
    layers.Conv2D(32,(5,5),activation='relu',input_shape=(28,28,1)),
    layers.MaxPooling2D(pool_size=(2,2)),

    layers.Conv2D(64, (3,3), activation='relu'),
    layers.MaxPooling2D(pool_size=(1,1)),
    
    layers.Flatten(),
    layers.Dense(512,activation='relu'),
    layers.Dense(10,activation='softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(x_train,y_train,epochs=10, batch_size=64,validation_data=(x_test,y_test))
# Out:
# Epoch 1/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 51s 53ms/step - accuracy: 0.8080 - loss: 0.5484 - val_accuracy: 0.8891 - val_loss: 0.3085
# Epoch 2/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 47s 50ms/step - accuracy: 0.9023 - loss: 0.2662 - val_accuracy: 0.8979 - val_loss: 0.2741
# Epoch 3/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 56s 60ms/step - accuracy: 0.9174 - loss: 0.2181 - val_accuracy: 0.9092 - val_loss: 0.2485
# Epoch 4/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 47s 50ms/step - accuracy: 0.9342 - loss: 0.1781 - val_accuracy: 0.9084 - val_loss: 0.2733
# Epoch 5/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 47s 50ms/step - accuracy: 0.9440 - loss: 0.1493 - val_accuracy: 0.9167 - val_loss: 0.2443
# Epoch 6/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 47s 50ms/step - accuracy: 0.9559 - loss: 0.1147 - val_accuracy: 0.9125 - val_loss: 0.2668
# Epoch 7/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 46s 49ms/step - accuracy: 0.9662 - loss: 0.0932 - val_accuracy: 0.9160 - val_loss: 0.2721
# Epoch 8/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 46s 49ms/step - accuracy: 0.9724 - loss: 0.0723 - val_accuracy: 0.9172 - val_loss: 0.2897
# Epoch 9/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 46s 49ms/step - accuracy: 0.9792 - loss: 0.0560 - val_accuracy: 0.9142 - val_loss: 0.3180
# Epoch 10/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 46s 49ms/step - accuracy: 0.9826 - loss: 0.0467 - val_accuracy: 0.9183 - val_loss: 0.3657

# %%
test_loss,test_acc=model.evaluate(x_test,y_test)
print(f"Точность модели на тестовых данных: {test_acc:.2f}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9181 - loss: 0.3777
# Точность модели на тестовых данных: 0.92
